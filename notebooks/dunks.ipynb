# %% [markdown]
# # Dunkin Donuts in New England
#
# Let's take a look at how prevalent Dunkin Donuts is in New England (Connecticut, Rhode Island, Massachusetts, Vermont, New Hampshire and Maine). The Dunkin Donuts dataset was initially run through a serialize script written by rgdonohue to build a GeoJSON object from the JSON. Data analysis is performed within this script, with one exception. The statePopCount dataset was created using the point in polygon tool within QGIS to create the 'Count' column which provides a count of Dunkin Donuts restaurants in each state.
#
#
# #### Data:
#
# Dunkin Donuts:
# https://www.kaggle.com/jpbulman/usa-dunkin-donuts-stores?select=dunkinDonuts.json
#
# Roadways:
# https://catalog.data.gov/dataset/tiger-line-shapefile-2016-nation-u-s-primary-roads-national-shapefile
#
# State:
# https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html
#
# Population:
# https://www.census.gov/data/tables/time-series/demo/popest/2010s-state-total.html

# %% [markdown]
# ## Load and Inspect Data
#
# Load desired packages and datasets. Inspect datasets after they're loaded.

# %%
# Load desired packages

# %matplotlib inline

import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# change default figsize
plt.rcParams['figure.figsize'] = (15, 12)

# %%
# Load desired datasets
dd = gpd.read_file('../map/data/dunkinDonuts2.geojson')
states = gpd.read_file('../map/data/cb_2018_us_state_5m/cb_2018_us_state_5m.shp')
highways = gpd.read_file('../map/data/tl_2016_us_primaryroads/tl_2016_us_primaryroads.shp')
pop = pd.read_csv('../map/data/statePop.csv')

# %%
# Inspect Dunkin Donuts data
dd.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9698 entries, 0 to 9697
# Data columns (total 69 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   hashKey                  9698 non-null   int64
#  1   geoJson                  9698 non-null   object
#  2   geohash                  9698 non-null   int64
#  3   recordId                 9698 non-null   object
#  4   address                  9698 non-null   object
#  5   address2                 9698 non-null   object
#  6   adv_ord                  9698 non-null   object
#  7   almond                   9698 non-null   object
#  8   beverageonly             9698 non-null   object
#  9   city                     9698 non-null   object
#  10  close_reason_cd          9698 non-null   object
#  11  co_brander_cd            9698 non-null   object
#  12  combostore               9698 non-null   object
#  13  country                  9698 non-null   object
#  14  county                   9698 non-null   object
#  15  dma_cd                   9698 non-null   object
#  16  drivein                  9698 non-null   object
#  17  dunkincardenabled        9698 non-null   object
#  18  faxnumber                9698 non-null   object
#  19  fri_hours                9698 non-null   object
#  20  k_cup                    9698 non-null   object
#  21  kosher                   9698 non-null   object
#  22  lat                      9698 non-null   object
#  23  lc                       9698 non-null   object
#  24  lng                      9698 non-null   object
#  25  loyalty                  9698 non-null   object
#  26  mobile                   9698 non-null   object
#  27  mon_hours                9698 non-null   object
#  28  name                     9698 non-null   object
#  29  operation_status_cd      9698 non-null   object
#  30  phonenumber              9698 non-null   object
#  31  postal                   9698 non-null   object
#  32  sat_hours                9698 non-null   object
#  33  sitetype                 9698 non-null   object
#  34  state                    9698 non-null   object
#  35  sun_hours                9698 non-null   object
#  36  thu_hours                9698 non-null   object
#  37  tue_hours                9698 non-null   object
#  38  turbooven                9698 non-null   object
#  39  website                  9698 non-null   object
#  40  wed_hours                9698 non-null   object
#  41  wireless                 9698 non-null   object
#  42  curbside                 9698 non-null   object
#  43  mon_cs_hours             9698 non-null   object
#  44  tue_cs_hours             9698 non-null   object
#  45  wed_cs_hours             9698 non-null   object
#  46  thu_cs_hours             9698 non-null   object
#  47  fri_cs_hours             9698 non-null   object
#  48  sat_cs_hours             9698 non-null   object
#  49  sun_cs_hours             9698 non-null   object
#  50  next_gen_store           9698 non-null   object
#  51  dt_auto_fire             9698 non-null   object
#  52  catering_flag            9698 non-null   object
#  53  mon_catering_hours       9698 non-null   object
#  54  tue_catering_hours       9698 non-null   object
#  55  wed_catering_hours       9698 non-null   object
#  56  thu_catering_hours       9698 non-null   object
#  57  fri_catering_hours       9698 non-null   object
#  58  sat_catering_hours       9698 non-null   object
#  59  sun_catering_hours       9698 non-null   object
#  60  distance                 9698 non-null   float64
#  61  tender_agnostic_enabled  9698 non-null   object
#  62  mobile_bypass_lane       9698 non-null   object
#  63  pos_cmc_id               9698 non-null   object
#  64  pos_type                 9698 non-null   object
#  65  last_updated_datetime    9698 non-null   object
#  66  dbi_fee_hr_link          9698 non-null   object
#  67  apply_online             9698 non-null   object
#  68  geometry                 9698 non-null   geometry
# dtypes: float64(1), geometry(1), int64(2), object(65)
# memory usage: 5.1+ MB

# %%
# Inspect Dunkin Donuts data
dd.head()
# Out:
#    hashKey                                            geoJson  \
# 0  -918298  {'coordinates': [37.649585, -122.40607], 'type...
# 1  -918297  {'coordinates': [37.737457, -122.197412], 'typ...
# 2  -918296  {'coordinates': [37.660518, -122.085634], 'typ...
# 3  -918294  {'coordinates': [37.510929, -122.265387], 'typ...
# 4  -918299  {'coordinates': [37.468452, -122.43279], 'type...
#
#                geohash recordId             address address2 adv_ord almond  \
# 0 -9182987302055287277   354702  180 S Airport Blvd                Y      N
# 1 -9182974066249403913   358272  451 Hegenberger Rd                Y      N
# 2 -9182961277602276619   358726      268 Jackson St                Y      N
# 3 -9182942986416200029   357824  240 El Camino Real                Y      N
# 4 -9182992808912999687   355538    118 San Mateo Rd                Y      N
#
#   beverageonly                 city  ... sun_catering_hours   distance  \
# 0            N  South San Francisco  ...                      8.685433
# 1            N              Oakland  ...                     12.394248
# 2            N              Hayward  ...                     19.872148
# 3            N           San Carlos  ...                     20.082637
# 4            N        Half Moon Bay  ...                     21.177412
#
#   tender_agnostic_enabled mobile_bypass_lane pos_cmc_id  pos_type  \
# 0                       Y                       1015019   Radiant
# 1                       Y                       1029676   Radiant
# 2                       Y                  N             Simphony
# 3                       Y                       1026927   Radiant
# 4                       Y                       1012486   Radiant
#
#   last_updated_datetime dbi_fee_hr_link apply_online  \
# 0         1584423000000                            N
# 1         1584423000000
# 2         1584423000000
# 3         1584423000000
# 4         1584423000000                            N
#
#                       geometry
# 0  POINT (-122.40607 37.64959)
# 1  POINT (-122.19741 37.73746)
# 2  POINT (-122.08563 37.66052)
# 3  POINT (-122.26539 37.51093)
# 4  POINT (-122.43279 37.46845)
#
# [5 rows x 69 columns]

# %%
# Inspect state data
states.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATEFP   56 non-null     object
#  1   STATENS   56 non-null     object
#  2   AFFGEOID  56 non-null     object
#  3   GEOID     56 non-null     object
#  4   STUSPS    56 non-null     object
#  5   NAME      56 non-null     object
#  6   LSAD      56 non-null     object
#  7   ALAND     56 non-null     int64
#  8   AWATER    56 non-null     int64
#  9   geometry  56 non-null     geometry
# dtypes: geometry(1), int64(2), object(7)
# memory usage: 4.5+ KB

# %%
# Inspect state data
states.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS          NAME LSAD  \
# 0      31  01779792  0400000US31    31     NE      Nebraska   00
# 1      53  01779804  0400000US53    53     WA    Washington   00
# 2      35  00897535  0400000US35    35     NM    New Mexico   00
# 3      46  01785534  0400000US46    46     SD  South Dakota   00
# 4      48  01779801  0400000US48    48     TX         Texas   00
#
#           ALAND       AWATER  \
# 0  198956658395   1371829134
# 1  172112588220  12559278850
# 2  314196306401    728776523
# 3  196346981786   3382720225
# 4  676653171537  19006305260
#
#                                             geometry
# 0  POLYGON ((-104.05351 41.15726, -104.05267 41.2...
# 1  MULTIPOLYGON (((-122.32834 48.02134, -122.3217...
# 2  POLYGON ((-109.05017 31.48000, -109.04984 31.4...
# 3  POLYGON ((-104.05770 44.99743, -104.05021 44.9...
# 4  POLYGON ((-106.64548 31.89867, -106.64084 31.9...

# %%
# Inspect population data
pop.head()
# Out:
#          STATE STUSPS    CENSUS   estBase      2010      2011      2012  \
# 0     .Alabama     AL   4779736   4780125   4785437   4799069   4815588
# 1      .Alaska     AK    710231    710249    713910    722128    730443
# 2     .Arizona     AZ   6392017   6392288   6407172   6472643   6554978
# 3    .Arkansas     AR   2915918   2916031   2921964   2940667   2952164
# 4  .California     CA  37253956  37254519  37319502  37638369  37948800
#
#        2013      2014      2015      2016      2017      2018      2019
# 0   4830081   4841799   4852347   4863525   4874486   4887681   4903185
# 1    737068    736283    737498    741456    739700    735139    731545
# 2   6632764   6730413   6829676   6941072   7044008   7158024   7278717
# 3   2959400   2967392   2978048   2989918   3001345   3009733   3017804
# 4  38260787  38596972  38918045  39167117  39358497  39461588  39512223

# %% [markdown]
# ## Merging Data
#
# The following cells merge the population CSV to the states shapefile. Write a new GeoJSON of the merged dataset. Then, create choropleth map of the United States 2019 population.

# %%
# Merge the States and Population datasets on the 'STUSPS' column

statePop = pd.merge(states, pop)
statePop
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0       31  01779792  0400000US31    31     NE        Nebraska   00
# 1       53  01779804  0400000US53    53     WA      Washington   00
# 2       35  00897535  0400000US35    35     NM      New Mexico   00
# 3       46  01785534  0400000US46    46     SD    South Dakota   00
# 4       48  01779801  0400000US48    48     TX           Texas   00
# 5       06  01779778  0400000US06    06     CA      California   00
# 6       21  01779786  0400000US21    21     KY        Kentucky   00
# 7       39  01085497  0400000US39    39     OH            Ohio   00
# 8       01  01779775  0400000US01    01     AL         Alabama   00
# 9       13  01705317  0400000US13    13     GA         Georgia   00
# 10      55  01779806  0400000US55    55     WI       Wisconsin   00
# 11      41  01155107  0400000US41    41     OR          Oregon   00
# 12      42  01779798  0400000US42    42     PA    Pennsylvania   00
# 13      28  01779790  0400000US28    28     MS     Mississippi   00
# 14      29  01779791  0400000US29    29     MO        Missouri   00
# 37    20205125364    7129925486
# 38   138949136250   31361101223
# 39    12542497068    1815617571
# 40    19047825980    3544860246
# 41    25151100280    6979966958
# 42    77864918488    5075218778
# 43    79887426037   11746549764
# 44    23189413166    1026675248
# 45   144661267977    1084180812
# 46   134768872727    2962859592
# 47   106802728188    2350123465
# 48   143780567633    6214824948
# 49  1478839695958  245481577452
#
#                                              geometry  ...      2010  \
# 0   POLYGON ((-104.05351 41.15726, -104.05267 41.2...  ...   1829542
# 1   MULTIPOLYGON (((-122.32834 48.02134, -122.3217...  ...   6742830
# 2   POLYGON ((-109.05017 31.48000, -109.04984 31.4...  ...   2064552
# 3   POLYGON ((-104.05770 44.99743, -104.05021 44.9...  ...    816166
# 4   POLYGON ((-106.64548 31.89867, -106.64084 31.9...  ...  25241971
# 5   MULTIPOLYGON (((-118.60337 33.47810, -118.5987...  ...  37319502
# 6   MULTIPOLYGON (((-89.40565 36.52817, -89.39869 ...  ...   4348181
# 7   MULTIPOLYGON (((-82.73571 41.60336, -82.71880 ...  ...  11539336
# 8   MULTIPOLYGON (((-88.04374 30.51742, -88.03661 ...  ...   4785437
# 9   POLYGON ((-85.60516 34.98468, -85.55259 34.984...  ...   9711881
# 10  MULTIPOLYGON (((-86.95620 45.35201, -86.95339 ...  ...   5690475
# 11  POLYGON ((-124.55244 42.84057, -124.50014 42.9...  ...   3837491
# 12  POLYGON ((-80.51989 40.90666, -80.51909 40.921...  ...  12711160
# 13  MULTIPOLYGON (((-88.51067 30.21702, -88.49238 ...  ...   2970548
# 14  POLYGON ((-95.77355 40.57820, -95.76853 40.583...  ...   5995974
# 15  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...  ...   9574323
# 16  POLYGON ((-103.00257 36.52659, -103.00219 36.6...  ...   3759944
# 17  POLYGON ((-82.64300 38.16956, -82.63905 38.171...  ...   1854239
# 18  MULTIPOLYGON (((-72.03496 41.25546, -72.02944 ...  ...  19399878
# 19  POLYGON ((-88.09566 37.90581, -88.08624 37.905...  ...   6490432
# 20  POLYGON ((-102.05174 40.00308, -101.91670 40.0...  ...   2858190
# 21  POLYGON ((-117.24267 44.39655, -117.23484 44.3...  ...   1570746
# 22  POLYGON ((-120.00574 39.22866, -120.00526 39.2...  ...   2702405
# 23  POLYGON ((-73.43774 44.04501, -73.43199 44.063...  ...    625879
# 24  POLYGON ((-116.04905 48.48102, -116.04905 48.5...  ...    990697
# 25  POLYGON ((-97.23921 48.96868, -97.23802 48.975...  ...   5310828
# 26  POLYGON ((-104.04865 48.86573, -104.04882 48.8...  ...    674715
# 27  MULTIPOLYGON (((-156.05722 19.74254, -156.0523...  ...   1363963
# 28  POLYGON ((-114.79968 32.59362, -114.80939 32.6...  ...   6407172
# 29  MULTIPOLYGON (((-75.57080 39.62677, -75.55945 ...  ...    899593
# 30  MULTIPOLYGON (((-71.36152 41.46483, -71.34707 ...  ...   1053959
# 31  POLYGON ((-109.06025 38.59933, -109.05954 38.7...  ...   5047349
# 32  POLYGON ((-114.05296 37.59278, -114.05247 37.6...  ...   2775332
# 26    685225    701176    722036    737401    754066    754434    754942
# 27   1379329   1394804   1408243   1414538   1422052   1427559   1424393
# 28   6472643   6554978   6632764   6730413   6829676   6941072   7044008
# 29    907381    915179    923576    932487    941252    948921    956823
# 30   1053649   1054621   1055081   1055936   1056065   1056770   1055673
# 31   5121108   5192647   5269035   5350101   5450623   5539215   5611885
# 32   2814384   2853375   2897640   2936879   2981835   3041868   3101042
# 33   8101155   8185080   8252427   8310993   8361808   8410106   8463587
# 34    567299    576305    582122    582531    585613    584215    578931
# 35   4575625   4600972   4624527   4644013   4664628   4678135   4670560
# 36   9882412   9897145   9913065   9929848   9931715   9950571   9973114
# 37   6613583   6663005   6713315   6762596   6794228   6823608   6859789
# 38  19053237  19297822  19545621  19845911  20209042  20613477  20963613
# 39   3588283   3594547   3594841   3594524   3587122   3578141   3573297
# 40   8828117   8844942   8856972   8864525   8867949   8870827   8885525
# 41   5839419   5886992   5923188   5957283   5985562   6003323   6023868
# 42   4671994   4717354   4764080   4823617   4891938   4957968   5021268
# 43   1328284   1327729   1328009   1330513   1328262   1331317   1334612
# 44   1320202   1324232   1326622   1333341   1336350   1342307   1348787
# 45   3066336   3076190   3092997   3109350   3120960   3131371   3141550
# 46   2940667   2952164   2959400   2967392   2978048   2989918   3001345
# 47   6399291   6453898   6494340   6541223   6591170   6646010   6708799
# 48  12867454  12882510  12895129  12884493  12858913  12820527  12778828
# 49    722128    730443    737068    736283    737498    741456    739700
#
#         2018      2019
# 0    1925614   1934408
# 1    7523869   7614893
# 2    2092741   2096829
# 3     878698    884659
# 4   28628666  28995881
# 5   39461588  39512223
# 6    4461153   4467673
# 7   11676341  11689100
# 8    4887681   4903185
# 9   10511131  10617423
# 10   5807406   5822434
# 11   4181886   4217737
# 12  12800922  12801989
# 13   2981020   2976149
# 14   6121623   6137428
# 15  10381615  10488084
# 16   3940235   3956971
# 17   1804291   1792147
# 18  19530351  19453561
# 19   6695497   6732219
# 20   2911359   2913314
# 21   1750536   1787065
# 22   3027341   3080156
# 23    624358    623989
# 24   1060665   1068778
# 25   5606249   5639632
# 26    758080    762062
# 27   1420593   1415872
# 28   7158024   7278717
# 29    965479    973764
# 30   1058287   1059361
# 31   5691287   5758736
# 32   3153550   3205958
# 33   8501286   8535519
# 34    577601    578759
# 35   4659690   4648794
# 36   9984072   9986857
# 37   6882635   6892503
# 38  21244317  21477737
# 39   3571520   3565287
# 40   8886025   8882190
# 41   6035802   6045680
# 42   5084156   5148714
# 43   1339057   1344212
# 44   1353465   1359711
# 45   3148618   3155070
# 46   3009733   3017804
# 47   6771631   6829174
# 48  12723071  12671821
# 49    735139    731545
#
# [50 rows x 23 columns]

# %%
# Create GeoJSON of statePop

statePop.to_file('../map/data/states_population.geojson', driver="GeoJSON")

# %% [markdown]
# ## Clipping data to New England
#
# Here, I create a dataframe of New England states, then combine them into a single polygon which I then use to clip the DD dataset and highway dataset.

# %%
# From state data let's pull out New England 
# (Connecticut, Rhode Island, Massachusetts, Vermont, New Hampshire and Maine)

ne = states[(states['STUSPS'] == 'CT') | (states['STUSPS'] == 'RI') | (states['STUSPS'] == 'MA') | (states['STUSPS'] == 'VT') | (states['STUSPS'] == 'NH') | (states['STUSPS'] == 'ME')]

ne
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS           NAME LSAD  \
# 23      50  01779802  0400000US50    50     VT        Vermont   00
# 30      44  01219835  0400000US44    44     RI   Rhode Island   00
# 37      25  00606926  0400000US25    25     MA  Massachusetts   00
# 40      09  01779780  0400000US09    09     CT    Connecticut   00
# 44      23  01779787  0400000US23    23     ME          Maine   00
# 45      33  01779794  0400000US33    33     NH  New Hampshire   00
#
#           ALAND       AWATER  \
# 23  23874175944   1030416650
# 30   2677779902   1323670487
# 37  20205125364   7129925486
# 40  12542497068   1815617571
# 44  79887426037  11746549764
# 45  23189413166   1026675248
#
#                                              geometry
# 23  POLYGON ((-73.43774 44.04501, -73.43199 44.063...
# 30  MULTIPOLYGON (((-71.36152 41.46483, -71.34707 ...
# 37  MULTIPOLYGON (((-70.27553 41.31046, -70.26063 ...
# 40  POLYGON ((-73.72777 41.10070, -73.69595 41.115...
# 44  MULTIPOLYGON (((-68.37659 44.11376, -68.37538 ...
# 45  POLYGON ((-72.55725 42.85302, -72.55423 42.860...

# %%
# Take a look at our handy work
ne.plot();

# %%
# Use unary_union to combine NE state polygons into single NE polygon

ne_poly = ne.geometry.unary_union

# %%
# Create new GeoDataFrame of points that intersect with the clipping polygon
# Dunkin Donuts in New England

ne_dd = dd[dd.geometry.intersects(ne_poly)]

ne_dd
# Out:
#       hashKey                                            geoJson  \
# 5594   553310  {'coordinates': [44.999292, -73.329912], 'type...
# 5970   553335  {'coordinates': [44.536617, -73.247342], 'type...
# 6053   553337  {'coordinates': [44.480493, -73.215511], 'type...
# 6076   553337  {'coordinates': [44.39629, -73.219413], 'type'...
# 6078   553337  {'coordinates': [44.459844, -73.207892], 'type...
# ...       ...                                                ...
# 9692   552561  {'coordinates': [44.523921, -68.398848], 'type...
# 9693   552561  {'coordinates': [44.51592, -68.39666], 'type':...
# 9694   552275  {'coordinates': [46.141994, -67.840564], 'type...
# 9695   552389  {'coordinates': [44.721585, -67.44721], 'type'...
# 9696   552309  {'coordinates': [45.181805, -67.285165], 'type...
#
#                   geohash recordId                address  address2 adv_ord  \
# 5594  5533103460413357459   353209       320 US Route 2 N   Jolly's       Y
# 5970  5533357990135674191   350520           25 Macrae Rd                 Y
# 6053  5533370268819983183   340015            80 Pearl St                 Y
# 6076  5533371646478366723   355063      4109 Shelburne Rd                 Y
# 6078  5533371080454227149   300403       206 Shelburne Rd                 Y
# ...                   ...      ...                    ...       ...     ...
# 9692  5525619745249323965   351144  15 Kingsland Crossing                 Y
# 9693  5525615496302821401   346855           17 Myrick St  Wal-Mart       Y
# 9694  5522751882830805181   336418           246 North St                 Y
# 9695  5523891348156326611   339701       300 East Main St                 Y
# 9696  5523094474210913373   302685           131 North St                 Y
#
#      almond beverageonly        city  ... sun_catering_hours     distance  \
# 5594      Y            N     Alburgh  ...                     2551.902282
# 5970      Y            N  Colchester  ...                     2559.674420
# 6053      Y            N  Burlington  ...        06:00-19:00  2561.710378
# 6076      Y            N   Shelburne  ...                     2562.250114
# 6078      Y            N  Burlington  ...        06:00-19:00  2562.261165
# ...     ...          ...         ...  ...                ...          ...
# 9692      Y            N   Ellsworth  ...                     2795.889288
# 9693      Y            N     Lamoine  ...                     2796.090065
# 9694      Y            N     Houlton  ...                     2805.016265
# 9695      Y            N     Machias  ...                     2839.584541
# 9696      Y            N      Calais  ...                     2841.895152
#
#      tender_agnostic_enabled mobile_bypass_lane pos_cmc_id pos_type  \
# 5594                       Y                     501307236  Radiant
# 5970                       Y                     501306277  Radiant
# 6053                       Y                     501303469  Radiant
# 6076                       Y                     501307702  Radiant
# 6078                       Y                     501300221  Radiant
# ...                      ...                ...        ...      ...
# 9692                       Y                  N  501306536  Radiant
# 9693                       Y                  N  501305382  Radiant
# 9694                       Y                     501302709  Radiant
# 9695                       Y                  N  501303392  Radiant
# 9696                       Y                  N  501300834  Radiant
#
#      last_updated_datetime            dbi_fee_hr_link apply_online  \
# 5594         1584423000000  https://www.vtdonuts.com/            Y
# 5970         1584423000000  https://www.vtdonuts.com/            Y
# 6053         1584423000000  https://www.vtdonuts.com/            Y
# 6076         1584423000000  https://www.vtdonuts.com/            Y
# 6078         1584423000000  https://www.vtdonuts.com/            Y
# ...                    ...                        ...          ...
# 9692         1584423000000                                       N
# 9693         1584423000000                                       N
# 9694         1584423000000                                       N
# 9695         1584423000000                                       N
# 9696         1584423000000                                       N
#
#                         geometry
# 5594  POINT (-73.32991 44.99929)
# 5970  POINT (-73.24734 44.53662)
# 6053  POINT (-73.21551 44.48049)
# 6076  POINT (-73.21941 44.39629)
# 6078  POINT (-73.20789 44.45984)
# ...                          ...
# 9692  POINT (-68.39885 44.52392)
# 9693  POINT (-68.39666 44.51592)
# 9694  POINT (-67.84056 46.14199)
# 9695  POINT (-67.44721 44.72158)
# 9696  POINT (-67.28517 45.18180)
#
# [2288 rows x 69 columns]

# %%
# Check out the DD's in NE!

fig, ax = plt.subplots()

base_color = '#f0f0f0'
marker_color = '#448ee4'

ne.plot(ax=ax, color=base_color, zorder=0);
ne_dd.plot(ax=ax, color=marker_color, markersize=30, zorder=1);

# %%
# Create a new GeoDataFrame by selecting the highways that intersect with the ne_poly

ne_hwys = highways[highways.geometry.intersects(ne_poly)]

# %%
# See how DD locations correlate to highways in NE

fig, ax = plt.subplots()

base_color = '#f0f0f0'
marker_color = '#448ee4'
color_road = 'green'

ne.plot(ax=ax, color=base_color, edgecolor='white', zorder=0);
ne_hwys.plot(ax=ax, color=color_road, zorder=2);
ne_dd.plot(ax=ax, color=marker_color, markersize=30, zorder=1);

# %% [markdown]
# ### Visualize Dunkin Donuts in New England
#
# Let's create a map that will visualize quantities of Dunkin Donuts by state. The statePopCount dataset was created using the point in polygon tool within QGIS to create the 'Count' column which provides a count of Dunkin Donuts restaurants in each state.

# %%
# Load dataset with population and count of DDs
statePopCount = gpd.read_file('../map/data/statePopCount.geojson') 
statePopCount
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSP
# 49    736283    737498    741456    739700    735139    731545     1.0
#
#                                              geometry
# 0   POLYGON ((-104.05351 41.15726, -104.05267 41.2...
# 1   MULTIPOLYGON (((-122.32834 48.02134, -122.3217...
# 2   POLYGON ((-109.05017 31.48000, -109.04984 31.4...
# 3   POLYGON ((-104.05770 44.99743, -104.05021 44.9...
# 4   POLYGON ((-106.64548 31.89867, -106.64084 31.9...
# 5   MULTIPOLYGON (((-118.60337 33.47810, -118.5987...
# 6   MULTIPOLYGON (((-89.40565 36.52817, -89.39869 ...
# 7   MULTIPOLYGON (((-82.73571 41.60336, -82.71880 ...
# 8   MULTIPOLYGON (((-88.04374 30.51742, -88.03661 ...
# 9   POLYGON ((-85.60516 34.98468, -85.55259 34.984...
# 10  MULTIPOLYGON (((-86.95620 45.35201, -86.95339 ...
# 11  POLYGON ((-124.55244 42.84057, -124.50014 42.9...
# 12  POLYGON ((-80.51989 40.90666, -80.51909 40.921...
# 13  MULTIPOLYGON (((-88.51067 30.21702, -88.49238 ...
# 14  POLYGON ((-95.77355 40.57820, -95.76853 40.583...
# 15  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...
# 16  POLYGON ((-103.00257 36.52659, -103.00219 36.6...
# 17  POLYGON ((-82.64300 38.16956, -82.63905 38.171...
# 18  MULTIPOLYGON (((-72.03496 41.25546, -72.02944 ...
# 19  POLYGON ((-88.09566 37.90581, -88.08624 37.905...
# 20  POLYGON ((-102.05174 40.00308, -101.91670 40.0...
# 21  POLYGON ((-117.24268 44.39655, -117.23484 44.3...
# 22  POLYGON ((-120.00574 39.22866, -120.00526 39.2...
# 23  POLYGON ((-73.43774 44.04501, -73.43199 44.063...
# 24  POLYGON ((-116.04905 48.48102, -116.04905 48.5...
# 25  POLYGON ((-97.23921 48.96868, -97.23802 48.975...
# 26  POLYGON ((-104.04865 48.86573, -104.04882 48.8...
# 27  MULTIPOLYGON (((-156.05722 19.74254, -156.0523...
# 28  POLYGON ((-114.79968 32.59362, -114.80939 32.6...
# 29  MULTIPOLYGON (((-75.57080 39.62677, -75.55945 ...
# 30  MULTIPOLYGON (((-71.36152 41.46483, -71.34707 ...
# 31  POLYGON ((-109.06025 38.59933, -109.05954 38.7...
# 32  POLYGON ((-114.05296 37.59278, -114.05247 37.6...
# 33  MULTIPOLYGON (((-75.99966 37.84820, -75.99686 ...
# 34  POLYGON ((-111.05689 44.86666, -111.05563 44.9...
# 35  MULTIPOLYGON (((-88.88145 30.05320, -88.87048 ...
# 36  MULTIPOLYGON (((-84.00966 46.10133, -83.98768 ...
# 37  MULTIPOLYGON (((-70.27553 41.31046, -70.26063 ...
# 38  MULTIPOLYGON (((-80.75164 24.85725, -80.72906 ...
# 39  POLYGON ((-73.72777 41.10070, -73.69595 41.115...
# 40  POLYGON ((-75.55910 39.62906, -75.55945 39.629...
# 41  MULTIPOLYGON (((-76.04940 37.99031, -76.04881 ...
# 42  POLYGON ((-83.35324 34.72865, -83.34883 34.737...
# 43  MULTIPOLYGON (((-68.37659 44.11376, -68.37538 ...
# 44  POLYGON ((-72.55725 42.85302, -72.55423 42.860...
# 45  POLYGON ((-96.63970 42.73707, -96.63589 42.741...
# 46  POLYGON ((-94.61792 36.49941, -94.55929 36.499...
# 47  POLYGON ((-90.30988 35.00975, -90.30690 35.018...
# 48  POLYGON ((-91.51297 40.18106, -91.51107 40.188...
# 49  MULTIPOLYGON (((179.48246 51.98283, 179.48657 ...
#
# [50 rows x 24 columns]

# %%
# Convert 'Count' column from string to float
statePopCount['Count'] = statePopCount.Count.astype(float)

# %%
# Pull out New England from the statePopCount dataset
nePopCount = statePopCount[(statePopCount['STUSPS'] == 'CT') | (statePopCount['STUSPS'] == 'RI') | (statePopCount['STUSPS'] == 'MA') | (statePopCount['STUSPS'] == 'VT') | (statePopCount['STUSPS'] == 'NH') | (statePopCount['STUSPS'] == 'ME')]

nePopCount
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS           NAME LSAD  \
# 23      50  01779802  0400000US50    50     VT        Vermont   00
# 30      44  01219835  0400000US44    44     RI   Rhode Island   00
# 37      25  00606926  0400000US25    25     MA  Massachusetts   00
# 39      09  01779780  0400000US09    09     CT    Connecticut   00
# 43      23  01779787  0400000US23    23     ME          Maine   00
# 44      33  01779794  0400000US33    33     NH  New Hampshire   00
#
#           ALAND       AWATER           STATE  ...     2012     2013     2014  \
# 23  23874175944   1030416650        .Vermont  ...   626090   626210   625214
# 30   2677779902   1323670487   .Rhode Island  ...  1054621  1055081  1055936
# 37  20205125364   7129925486  .Massachusetts  ...  6663005  6713315  6762596
# 39  12542497068   1815617571    .Connecticut  ...  3594547  3594841  3594524
# 43  79887426037  11746549764          .Maine  ...  1327729  1328009  1330513
# 44  23189413166   1026675248  .New Hampshire  ...  1324232  1326622  1333341
#
#        2015     2016     2017     2018     2019   Count  \
# 23   625216   623657   624344   624358   623989    52.0
# 30  1056065  1056770  1055673  1058287  1059361   175.0
# 37  6794228  6823608  6859789  6882635  6892503  1156.0
# 39  3587122  3578141  3573297  3571520  3565287   524.0
# 43  1328262  1331317  1334612  1339057  1344212   161.0
# 44  1336350  1342307  1348787  1353465  1359711   220.0
#
#                                              geometry
# 23  POLYGON ((-73.43774 44.04501, -73.43199 44.063...
# 30  MULTIPOLYGON (((-71.36152 41.46483, -71.34707 ...
# 37  MULTIPOLYGON (((-70.27553 41.31046, -70.26063 ...
# 39  POLYGON ((-73.72777 41.10070, -73.69595 41.115...
# 43  MULTIPOLYGON (((-68.37659 44.11376, -68.37538 ...
# 44  POLYGON ((-72.55725 42.85302, -72.55423 42.860...
#
# [6 rows x 24 columns]

# %%
# Create choropleth map of Dunkin Donuts in New England

# set the value column that will be visualized
variable = 'Count'

# set the range for the choropleth values
vmin = min(nePopCount['Count'])
vmax = max(nePopCount['Count'])

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30,10))

# Create colorbar legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm.set_array([])

# add the colorbar to the figure
fig.colorbar(sm, orientation="horizontal", fraction=0.036, pad=0.1, aspect = 30)

# create map
nePopCount.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8');

# %%
# Now let's see how New England compares to the rest of the country

# set the value column that will be visualized
variable = 'Count'

# set the range for the choropleth values
vmin = min(statePopCount['Count'])
vmax = max(statePopCount['Count'])

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30,10))

# Create colorbar legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm.set_array([])

# add the colorbar to the figure
fig.colorbar(sm, orientation="horizontal", fraction=0.036, pad=0.1, aspect = 30)

# create map
statePopCount.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8');

# %% [markdown]
# ## Cleaning Dunkin Donuts Data for Web Mapping
#
# I'd like to now clean up the dataset to use for web mapping. This is where I'll drop unnecessary columns

# %%
dd.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9698 entries, 0 to 9697
# Data columns (total 69 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   hashKey                  9698 non-null   int64
#  1   geoJson                  9698 non-null   object
#  2   geohash                  9698 non-null   int64
#  3   recordId                 9698 non-null   object
#  4   address                  9698 non-null   object
#  5   address2                 9698 non-null   object
#  6   adv_ord                  9698 non-null   object
#  7   almond                   9698 non-null   object
#  8   beverageonly             9698 non-null   object
#  9   city                     9698 non-null   object
#  10  close_reason_cd          9698 non-null   object
#  11  co_brander_cd            9698 non-null   object
#  12  combostore               9698 non-null   object
#  13  country                  9698 non-null   object
#  14  county                   9698 non-null   object
#  15  dma_cd                   9698 non-null   object
#  16  drivein                  9698 non-null   object
#  17  dunkincardenabled        9698 non-null   object
#  18  faxnumber                9698 non-null   object
#  19  fri_hours                9698 non-null   object
#  20  k_cup                    9698 non-null   object
#  21  kosher                   9698 non-null   object
#  22  lat                      9698 non-null   object
#  23  lc                       9698 non-null   object
#  24  lng                      9698 non-null   object
#  25  loyalty                  9698 non-null   object
#  26  mobile                   9698 non-null   object
#  27  mon_hours                9698 non-null   object
#  28  name                     9698 non-null   object
#  29  operation_status_cd      9698 non-null   object
#  30  phonenumber              9698 non-null   object
#  31  postal                   9698 non-null   object
#  32  sat_hours                9698 non-null   object
#  33  sitetype                 9698 non-null   object
#  34  state                    9698 non-null   object
#  35  sun_hours                9698 non-null   object
#  36  thu_hours                9698 non-null   object
#  37  tue_hours                9698 non-null   object
#  38  turbooven                9698 non-null   object
#  39  website                  9698 non-null   object
#  40  wed_hours                9698 non-null   object
#  41  wireless                 9698 non-null   object
#  42  curbside                 9698 non-null   object
#  43  mon_cs_hours             9698 non-null   object
#  44  tue_cs_hours             9698 non-null   object
#  45  wed_cs_hours             9698 non-null   object
#  46  thu_cs_hours             9698 non-null   object
#  47  fri_cs_hours             9698 non-null   object
#  48  sat_cs_hours             9698 non-null   object
#  49  sun_cs_hours             9698 non-null   object
#  50  next_gen_store           9698 non-null   object
#  51  dt_auto_fire             9698 non-null   object
#  52  catering_flag            9698 non-null   object
#  53  mon_catering_hours       9698 non-null   object
#  54  tue_catering_hours       9698 non-null   object
#  55  wed_catering_hours       9698 non-null   object
#  56  thu_catering_hours       9698 non-null   object
#  57  fri_catering_hours       9698 non-null   object
#  58  sat_catering_hours       9698 non-null   object
#  59  sun_catering_hours       9698 non-null   object
#  60  distance                 9698 non-null   float64
#  61  tender_agnostic_enabled  9698 non-null   object
#  62  mobile_bypass_lane       9698 non-null   object
#  63  pos_cmc_id               9698 non-null   object
#  64  pos_type                 9698 non-null   object
#  65  last_updated_datetime    9698 non-null   object
#  66  dbi_fee_hr_link          9698 non-null   object
#  67  apply_online             9698 non-null   object
#  68  geometry                 9698 non-null   geometry
# dtypes: float64(1), geometry(1), int64(2), object(65)
# memory usage: 5.1+ MB

# %%
# drop unwanted columns

dd.drop(['address2', 'adv_ord', 'almond', 'beverageonly', 'close_reason_cd', 'co_brander_cd', 'combostore', 'dma_cd', 'dunkincardenabled', 'faxnumber', 'k_cup', 'kosher', 'loyalty', 'mobile', 'operation_status_cd', 'sitetype', 'turbooven', 'website', 'wireless', 'curbside', 'mon_cs_hours', 'tue_cs_hours', 'wed_cs_hours', 'thu_cs_hours', 'fri_cs_hours', 'sat_cs_hours', 'sun_cs_hours', 'next_gen_store', 'dt_auto_fire', 'catering_flag', 'mon_catering_hours', 'tue_catering_hours', 'wed_catering_hours', 'thu_catering_hours', 'fri_catering_hours', 'sat_catering_hours', 'sun_catering_hours', 'distance', 'tender_agnostic_enabled', 'mobile_bypass_lane', 'pos_cmc_id', 'pos_type', 'last_updated_datetime', 'dbi_fee_hr_link', 'apply_online'], axis=1, inplace=True)

# %%
dd.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9698 entries, 0 to 9697
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hashKey      9698 non-null   int64
#  1   geoJson      9698 non-null   object
#  2   geohash      9698 non-null   int64
#  3   recordId     9698 non-null   object
#  4   address      9698 non-null   object
#  5   city         9698 non-null   object
#  6   country      9698 non-null   object
#  7   county       9698 non-null   object
#  8   drivein      9698 non-null   object
#  9   fri_hours    9698 non-null   object
#  10  lat          9698 non-null   object
#  11  lc           9698 non-null   object
#  12  lng          9698 non-null   object
#  13  mon_hours    9698 non-null   object
#  14  name         9698 non-null   object
#  15  phonenumber  9698 non-null   object
#  16  postal       9698 non-null   object
#  17  sat_hours    9698 non-null   object
#  18  state        9698 non-null   object
#  19  sun_hours    9698 non-null   object
#  20  thu_hours    9698 non-null   object
#  21  tue_hours    9698 non-null   object
#  22  wed_hours    9698 non-null   object
#  23  geometry     9698 non-null   geometry
# dtypes: geometry(1), int64(2), object(21)
# memory usage: 1.8+ MB

# %%
# Create GeoJSON of cleaned Dunkin Donuts data

dd.to_file('../map/data/dunkinClean.geojson', driver="GeoJSON")

# %% [markdown]
# ## Reprojection
#
# I reproject the New England datasets to an Azimuthal Equidistant projection to show accurate spatial relations between Dunkin Donut locations.

# %%
# Reproject datasets to Equidistant projection
# modified Proj4 projection string
# World Azimuthal Equidistant

proj_params = '+proj=ob_tran +o_proj=moll +o_lat_p=45 +o_lon_p=-90 +lon_0=-70' # ' +proj=aeqd +lat_0=0 +lon_0=0 +x_0=0 +y_0=0 +ellps=WGS84 +datum=WGS84 +units=m no_defs'

fig, ax = plt.subplots()

ne_projected = ne.to_crs(proj_params)
ne_hwys_projected = ne_hwys.to_crs(proj_params)
ne_dd_projected = ne_dd.to_crs(proj_params)

ne_projected.plot(ax=ax, color=base_color, edgecolor='white', zorder=0);
ne_hwys_projected.plot(ax=ax, color=color_road, zorder=2);
ne_dd_projected.plot(ax=ax, color=marker_color, markersize=30, zorder=1);
